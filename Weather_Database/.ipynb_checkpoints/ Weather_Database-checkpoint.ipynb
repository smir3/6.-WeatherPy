# %%
# DELIVERABLE 1. Create a new set of 2,000 random latitudes and Longitudes
import numpy as np
import pandas as pd
import random
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000.
# %timeit latitudes(2000)
# Out:
# 6.01 ms ± 336 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
lats = np.random.uniform(low=-120.000, high=140.000, size=2000)
lngs = np.random.uniform(low=-200.000, high=220.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 6.1.5: Use the tuple() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Add url definition
# Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6.1.5: Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 502

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-10, 20, 2000)
lngs = np.random.uniform(-30, 30, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
weather_api_key
# Out:
# 'd9f197b8c1d7eac49de31388ee894caa'

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | terney
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | bucerias
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | whitehorse
# Processing Record 12 of Set 1 | waipawa
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | quatre cocos
# Processing Record 16 of Set 1 | carpinteria
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | jacareacanga
# Processing Record 25 of Set 1 | dunedin
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | talnakh
# Processing Record 32 of Set 1 | yulara
# Processing Record 33 of Set 1 | tolaga bay
# Processing Record 34 of Set 1 | krasnoselkup
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | north platte
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | villa carlos paz
# Processing Record 42 of Set 1 | praya
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | asau
# Processing Record 47 of Set 1 | dubbo
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | beringovskiy
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | egvekinot
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | vilhena
# Processing Record 7 of Set 2 | port hardy
# Processing Record 8 of Set 2 | talara
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | nieuw amsterdam
# Processing Record 11 of Set 2 | kimberley
# Processing Record 12 of Set 2 | camacha
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | kirovskiy
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | kudahuvadhoo
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | casa grande
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | erzin
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | huarmey
# Processing Record 36 of Set 2 | iancu jianu
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | fairbanks
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | cururupu
# Processing Record 42 of Set 2 | roald
# Processing Record 43 of Set 2 | lagoa
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | avera
# Processing Record 46 of Set 2 | waverly
# Processing Record 47 of Set 2 | dvur kralove
# City not found. Skipping...
# Processing Record 48 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 2 | sorong
# Processing Record 50 of Set 2 | port macquarie
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | hualmay
# Processing Record 3 of Set 3 | dingle
# Processing Record 4 of Set 3 | scarborough
# Processing Record 5 of Set 3 | dwarka
# Processing Record 6 of Set 3 | carutapera
# Processing Record 7 of Set 3 | sisimiut
# Processing Record 8 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | stykkisholmur
# Processing Record 12 of Set 3 | makrana
# Processing Record 13 of Set 3 | todos santos
# Processing Record 14 of Set 3 | ballina
# Processing Record 15 of Set 3 | mezen
# Processing Record 16 of Set 3 | kendrapara
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | chimoio
# Processing Record 19 of Set 3 | salta
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | fethiye
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | sechura
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | bayji
# Processing Record 30 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 3 | lumphat
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | kidal
# Processing Record 35 of Set 3 | ushtobe
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | sheltozero
# Processing Record 38 of Set 3 | sukpak
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | bambous virieux
# Processing Record 42 of Set 3 | juneau
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | maumere
# Processing Record 47 of Set 3 | sao felix do xingu
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | buchanan
# Processing Record 50 of Set 3 | qafsah
# City not found. Skipping...
# Processing Record 1 of Set 4 | teguise
# Processing Record 2 of Set 4 | port moresby
# Processing Record 3 of Set 4 | kutum
# Processing Record 4 of Set 4 | batemans bay
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | kupang
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | iskateley
# Processing Record 9 of Set 4 | catole do rocha
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | lantana
# Processing Record 12 of Set 4 | nancha
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | boyolangu
# Processing Record 15 of Set 4 | saa
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | gafanha da encarnacao
# Processing Record 20 of Set 4 | ritchie
# Processing Record 21 of Set 4 | bandar-e anzali
# Processing Record 22 of Set 4 | whyalla
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | tautira
# Processing Record 26 of Set 4 | iisalmi
# Processing Record 27 of Set 4 | takoradi
# Processing Record 28 of Set 4 | tynset
# Processing Record 29 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 4 | urucara
# Processing Record 31 of Set 4 | bhuj
# Processing Record 32 of Set 4 | novyye burasy
# Processing Record 33 of Set 4 | ramsar
# Processing Record 34 of Set 4 | nishihara
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | taguatinga
# Processing Record 37 of Set 4 | muncar
# Processing Record 38 of Set 4 | la orilla
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | kapaa
# Processing Record 41 of Set 4 | ostrovnoy
# Processing Record 42 of Set 4 | abay
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | chapais
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | kokopo
# Processing Record 47 of Set 4 | puerto del rosario
# Processing Record 48 of Set 4 | nyurba
# Processing Record 49 of Set 4 | vangaindrano
# Processing Record 50 of Set 4 | banda aceh
# Processing Record 1 of Set 5 | hami
# Processing Record 2 of Set 5 | levikha
# Processing Record 3 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 4 of Set 5 | suntar
# Processing Record 5 of Set 5 | jingdezhen
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | iqaluit
# Processing Record 8 of Set 5 | tshikapa
# Processing Record 9 of Set 5 | taloqan
# Processing Record 10 of Set 5 | los llanos de aridane
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | baghdad
# Processing Record 13 of Set 5 | sembe
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | woodstock
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | champerico
# Processing Record 22 of Set 5 | phangnga
# Processing Record 23 of Set 5 | xingyi
# Processing Record 24 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 5 | uinskoye
# Processing Record 26 of Set 5 | roros
# Processing Record 27 of Set 5 | soto la marina
# Processing Record 28 of Set 5 | jakar
# Processing Record 29 of Set 5 | taoudenni
# Processing Record 30 of Set 5 | gorontalo
# Processing Record 31 of Set 5 | halifax
# Processing Record 32 of Set 5 | rocha
# Processing Record 33 of Set 5 | olkhovka
# Processing Record 34 of Set 5 | bako
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | chililabombwe
# City not found. Skipping...
# Processing Record 37 of Set 5 | shimoda
# Processing Record 38 of Set 5 | preobrazheniye
# Processing Record 39 of Set 5 | badaojiang
# City not found. Skipping...
# Processing Record 40 of Set 5 | verkhoyansk
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | magistralnyy
# Processing Record 43 of Set 5 | san blas
# City not found. Skipping...
# Processing Record 44 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 5 | damghan
# Processing Record 46 of Set 5 | chapleau
# Processing Record 47 of Set 5 | newport
# City not found. Skipping...
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | othonoi
# City not found. Skipping...
# Processing Record 50 of Set 5 | gushikawa
# Processing Record 1 of Set 6 | monster
# Processing Record 2 of Set 6 | calamar
# Processing Record 3 of Set 6 | constitucion
# Processing Record 4 of Set 6 | verkhovye
# Processing Record 5 of Set 6 | dandong
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | nacala
# Processing Record 9 of Set 6 | alice springs
# Processing Record 10 of Set 6 | hammond
# Processing Record 11 of Set 6 | rafai
# Processing Record 12 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | villa bruzual
# Processing Record 15 of Set 6 | high level
# Processing Record 16 of Set 6 | ahuimanu
# Processing Record 17 of Set 6 | quito
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | tsaratanana
# Processing Record 21 of Set 6 | varnavino
# Processing Record 22 of Set 6 | miyako
# Processing Record 23 of Set 6 | sandane
# Processing Record 24 of Set 6 | koch bihar
# Processing Record 25 of Set 6 | kerema
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | waiuku
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | shonguy
# Processing Record 30 of Set 6 | poyarkovo
# Processing Record 31 of Set 6 | agirish
# Processing Record 32 of Set 6 | tadine
# Processing Record 33 of Set 6 | kyabe
# Processing Record 34 of Set 6 | shingu
# City not found. Skipping...
# Processing Record 35 of Set 6 | tezu
# Processing Record 36 of Set 6 | aykhal
# Processing Record 37 of Set 6 | turayf
# Processing Record 38 of Set 6 | careiro da varzea
# Processing Record 39 of Set 6 | souillac
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | swift current
# Processing Record 42 of Set 6 | shubarkuduk
# Processing Record 43 of Set 6 | safranbolu
# Processing Record 44 of Set 6 | abalak
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | alta floresta
# Processing Record 48 of Set 6 | turukhansk
# Processing Record 49 of Set 6 | krasnouralsk
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | arona
# Processing Record 2 of Set 7 | benguela
# Processing Record 3 of Set 7 | tacna
# Processing Record 4 of Set 7 | chakradharpur
# Processing Record 5 of Set 7 | curumani
# Processing Record 6 of Set 7 | nanortalik
# Processing Record 7 of Set 7 | kompaniyivka
# Processing Record 8 of Set 7 | teluknaga
# Processing Record 9 of Set 7 | kroya
# Processing Record 10 of Set 7 | ponta delgada
# Processing Record 11 of Set 7 | belaya gora
# Processing Record 12 of Set 7 | manaure
# Processing Record 13 of Set 7 | nelson bay
# Processing Record 14 of Set 7 | cam ranh
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 7 | flin flon
# Processing Record 18 of Set 7 | dukat
# Processing Record 19 of Set 7 | tiarei
# Processing Record 20 of Set 7 | abu dhabi
# Processing Record 21 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 7 | san policarpo
# Processing Record 23 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | trincomalee
# Processing Record 26 of Set 7 | muros
# Processing Record 27 of Set 7 | nouakchott
# Processing Record 28 of Set 7 | tura
# Processing Record 29 of Set 7 | podyuga
# Processing Record 30 of Set 7 | chivilcoy
# Processing Record 31 of Set 7 | saint-leu
# Processing Record 32 of Set 7 | northam
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | dolzhanskaya
# Processing Record 35 of Set 7 | seoul
# Processing Record 36 of Set 7 | straumen
# Processing Record 37 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 7 | komsomolets
# Processing Record 39 of Set 7 | svobodnyy
# Processing Record 40 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 7 | phuket
# Processing Record 42 of Set 7 | sobolevo
# Processing Record 43 of Set 7 | zunheboto
# Processing Record 44 of Set 7 | ust-kuyga
# Processing Record 45 of Set 7 | hay river
# Processing Record 46 of Set 7 | itarema
# Processing Record 47 of Set 7 | itoman
# Processing Record 48 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 7 | vanderhoof
# Processing Record 50 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 8 | bairiki
# Processing Record 2 of Set 8 | huilong
# Processing Record 3 of Set 8 | saint george
# Processing Record 4 of Set 8 | sumbe
# Processing Record 5 of Set 8 | portree
# Processing Record 6 of Set 8 | rio gallegos
# Processing Record 7 of Set 8 | toledo
# Processing Record 8 of Set 8 | presidencia roque saenz pena
# Processing Record 9 of Set 8 | vao
# Processing Record 10 of Set 8 | laredo
# Processing Record 11 of Set 8 | san quintin
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | montijo
# Processing Record 14 of Set 8 | kjellerup
# Processing Record 15 of Set 8 | gat
# Processing Record 16 of Set 8 | charters towers
# Processing Record 17 of Set 8 | antofagasta
# Processing Record 18 of Set 8 | auki
# Processing Record 19 of Set 8 | nanakuli
# Processing Record 20 of Set 8 | sakaiminato
# Processing Record 21 of Set 8 | palmer
# Processing Record 22 of Set 8 | yuli
# Processing Record 23 of Set 8 | vyshhorod
# Processing Record 24 of Set 8 | mount isa
# Processing Record 25 of Set 8 | flinders
# Processing Record 26 of Set 8 | port hedland
# Processing Record 27 of Set 8 | cayenne
# Processing Record 28 of Set 8 | gasa
# Processing Record 29 of Set 8 | cabo san lucas
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | nicoya
# Processing Record 32 of Set 8 | workington
# Processing Record 33 of Set 8 | yertsevo
# Processing Record 34 of Set 8 | sabzevar
# Processing Record 35 of Set 8 | panaba
# Processing Record 36 of Set 8 | nogales
# Processing Record 37 of Set 8 | zaysan
# Processing Record 38 of Set 8 | geraldton
# Processing Record 39 of Set 8 | banjar
# Processing Record 40 of Set 8 | dabakala
# Processing Record 41 of Set 8 | road town
# Processing Record 42 of Set 8 | yabrud
# Processing Record 43 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 8 | piopio
# Processing Record 45 of Set 8 | prachatice
# Processing Record 46 of Set 8 | antalaha
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | sai buri
# Processing Record 49 of Set 8 | prachuap khiri khan
# Processing Record 50 of Set 8 | pacific grove
# Processing Record 1 of Set 9 | mandalgovi
# Processing Record 2 of Set 9 | verkhovazhye
# Processing Record 3 of Set 9 | soyo
# Processing Record 4 of Set 9 | margate
# Processing Record 5 of Set 9 | sale
# Processing Record 6 of Set 9 | kununurra
# Processing Record 7 of Set 9 | isangel
# Processing Record 8 of Set 9 | lewistown
# Processing Record 9 of Set 9 | palu
# Processing Record 10 of Set 9 | florian
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | gillette
# Processing Record 13 of Set 9 | herborn
# Processing Record 14 of Set 9 | umm lajj
# Processing Record 15 of Set 9 | pisco
# Processing Record 16 of Set 9 | eyl
# Processing Record 17 of Set 9 | mount gambier
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | terrace
# Processing Record 20 of Set 9 | san pedro
# Processing Record 21 of Set 9 | uige
# Processing Record 22 of Set 9 | arcata
# Processing Record 23 of Set 9 | alekseyevka
# Processing Record 24 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 9 | richards bay
# Processing Record 28 of Set 9 | prince rupert
# Processing Record 29 of Set 9 | piranshahr
# Processing Record 30 of Set 9 | stavern
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | kamenka
# Processing Record 33 of Set 9 | rovinj
# Processing Record 34 of Set 9 | baruun-urt
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | shetpe
# Processing Record 37 of Set 9 | la paz
# Processing Record 38 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 9 | key west
# Processing Record 40 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 9 | taksimo
# Processing Record 42 of Set 9 | sosnogorsk
# Processing Record 43 of Set 9 | rudnaya pristan
# Processing Record 44 of Set 9 | susaki
# Processing Record 45 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 9 | arzgir
# Processing Record 47 of Set 9 | alvaraes
# Processing Record 48 of Set 9 | nizhniy kuranakh
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | saint andrews
# Processing Record 1 of Set 10 | srikakulam
# Processing Record 2 of Set 10 | brenham
# Processing Record 3 of Set 10 | puerto quijarro
# City not found. Skipping...
# Processing Record 4 of Set 10 | mayor pablo lagerenza
# Processing Record 5 of Set 10 | koumac
# Processing Record 6 of Set 10 | coahuayana
# Processing Record 7 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 10 | skjervoy
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | varlamovo
# Processing Record 13 of Set 10 | broome
# Processing Record 14 of Set 10 | lakatoro
# Processing Record 15 of Set 10 | ferrol
# Processing Record 16 of Set 10 | nijar
# Processing Record 17 of Set 10 | birjand
# Processing Record 18 of Set 10 | ancud
# Processing Record 19 of Set 10 | katherine
# Processing Record 20 of Set 10 | casablanca
# Processing Record 21 of Set 10 | codrington
# Processing Record 22 of Set 10 | horsham
# Processing Record 23 of Set 10 | pong
# Processing Record 24 of Set 10 | slonim
# Processing Record 25 of Set 10 | ornskoldsvik
# Processing Record 26 of Set 10 | coihaique
# Processing Record 27 of Set 10 | la libertad
# Processing Record 28 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 10 | serro
# Processing Record 30 of Set 10 | sur
# Processing Record 31 of Set 10 | deputatskiy
# Processing Record 32 of Set 10 | salym
# Processing Record 33 of Set 10 | nautla
# Processing Record 34 of Set 10 | liverpool
# Processing Record 35 of Set 10 | kahului
# Processing Record 36 of Set 10 | sinnamary
# Processing Record 37 of Set 10 | kasongo-lunda
# Processing Record 38 of Set 10 | san andres
# Processing Record 39 of Set 10 | paciran
# Processing Record 40 of Set 10 | popondetta
# Processing Record 41 of Set 10 | matara
# Processing Record 42 of Set 10 | kyzyl-mazhalyk
# Processing Record 43 of Set 10 | vezirkopru
# Processing Record 44 of Set 10 | moscow
# Processing Record 45 of Set 10 | abbeville
# Processing Record 46 of Set 10 | mountmellick
# Processing Record 47 of Set 10 | ahipara
# Processing Record 48 of Set 10 | marawi
# Processing Record 49 of Set 10 | ocampo
# Processing Record 50 of Set 10 | lavrentiya
# Processing Record 1 of Set 11 | adrar
# Processing Record 2 of Set 11 | faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 478

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | raga
# Processing Record 2 of the Set 1 | tambura
# Processing Record 3 of the Set 1 | impfondo
# Processing Record 4 of the Set 1 | sal rei
# Processing Record 5 of the Set 1 | touros
# Processing Record 6 of the Set 1 | saint-louis
# Processing Record 7 of the Set 1 | bangassou
# Processing Record 8 of the Set 1 | kalemie
# Processing Record 9 of the Set 1 | georgetown
# Processing Record 10 of the Set 1 | umm kaddadah
# Processing Record 11 of the Set 1 | praia
# Processing Record 12 of the Set 1 | harper
# Processing Record 13 of the Set 1 | ndele
# Processing Record 14 of the Set 1 | am timan
# Processing Record 15 of the Set 1 | tonj
# Processing Record 16 of the Set 1 | ponta do sol
# Processing Record 17 of the Set 1 | birnin kebbi
# Processing Record 18 of the Set 1 | nouakchott
# Processing Record 19 of the Set 1 | fianga
# Processing Record 20 of the Set 1 | yokadouma
# Processing Record 21 of the Set 1 | san
# Processing Record 22 of the Set 1 | mattru
# Processing Record 23 of the Set 1 | takoradi
# Processing Record 24 of the Set 1 | luanda
# Processing Record 25 of the Set 1 | soyo
# Processing Record 26 of the Set 1 | kabare
# Processing Record 27 of the Set 1 | monrovia
# Processing Record 28 of the Set 1 | richard toll
# Processing Record 29 of the Set 1 | gamba
# Processing Record 30 of the Set 1 | nchelenge
# Processing Record 31 of the Set 1 | malanje
# Processing Record 32 of the Set 1 | boke
# Processing Record 33 of the Set 1 | lambarene
# Processing Record 34 of the Set 1 | sao filipe
# Processing Record 35 of the Set 1 | mayahi
# Processing Record 36 of the Set 1 | watsa
# Processing Record 37 of the Set 1 | yenagoa
# Processing Record 38 of the Set 1 | shaki
# Processing Record 39 of the Set 1 | bandundu
# Processing Record 40 of the Set 1 | araouane
# Processing Record 41 of the Set 1 | goderich
# Processing Record 42 of the Set 1 | olinda
# Processing Record 43 of the Set 1 | lai
# Processing Record 44 of the Set 1 | bababe
# Processing Record 45 of the Set 1 | sokoto
# Processing Record 46 of the Set 1 | santa maria
# Processing Record 47 of the Set 1 | tiebissou
# Processing Record 48 of the Set 1 | amlame
# Processing Record 49 of the Set 1 | damaturu
# Processing Record 50 of the Set 1 | bouza
# Processing Record 1 of the Set 2 | djenne
# Processing Record 2 of the Set 2 | lodja
# Processing Record 3 of the Set 2 | dakar
# Processing Record 4 of the Set 2 | bubaque
# Processing Record 5 of the Set 2 | dosso
# Processing Record 6 of the Set 2 | moanda
# Processing Record 7 of the Set 2 | kamina
# Processing Record 8 of the Set 2 | robertsport
# Processing Record 9 of the Set 2 | tanout
# Processing Record 10 of the Set 2 | kutum
# Processing Record 11 of the Set 2 | nioro
# Processing Record 12 of the Set 2 | tessaoua
# Processing Record 13 of the Set 2 | kembe
# Processing Record 14 of the Set 2 | boromo
# Processing Record 15 of the Set 2 | jamestown
# Processing Record 16 of the Set 2 | forecariah
# Processing Record 17 of the Set 2 | ngama
# Processing Record 18 of the Set 2 | riaba
# City not found. Skipping...
# Processing Record 19 of the Set 2 | omboue
# Processing Record 20 of the Set 2 | oussouye
# Processing Record 21 of the Set 2 | tombouctou
# Processing Record 22 of the Set 2 | gogrial
# Processing Record 23 of the Set 2 | lucapa
# Processing Record 24 of the Set 2 | goure
# Processing Record 25 of the Set 2 | mayumba
# Processing Record 26 of the Set 2 | kasongo-lunda
# Processing Record 27 of the Set 2 | pombas
# Processing Record 28 of the Set 2 | ouadda
# Processing Record 29 of the Set 2 | kerouane
# Processing Record 30 of the Set 2 | conakry
# Processing Record 31 of the Set 2 | bilma
# Processing Record 32 of the Set 2 | kaputa
# Processing Record 33 of the Set 2 | wamba
# Processing Record 34 of the Set 2 | mweka
# Processing Record 35 of the Set 2 | sangueya
# Processing Record 36 of the Set 2 | brazzaville
# Processing Record 37 of the Set 2 | bonthe
# Processing Record 38 of the Set 2 | port-gentil
# Processing Record 39 of the Set 2 | sapele
# Processing Record 40 of the Set 2 | axim
# Processing Record 41 of the Set 2 | moussoro
# Processing Record 42 of the Set 2 | anloga
# Processing Record 43 of the Set 2 | beyla
# Processing Record 44 of the Set 2 | ouidah
# Processing Record 45 of the Set 2 | inongo
# Processing Record 46 of the Set 2 | bitam
# Processing Record 47 of the Set 2 | kedougou
# Processing Record 48 of the Set 2 | lagos
# Processing Record 49 of the Set 2 | kasongo
# Processing Record 50 of the Set 2 | warri
# Processing Record 1 of the Set 3 | libenge
# Processing Record 2 of the Set 3 | ewo
# Processing Record 3 of the Set 3 | lafia
# Processing Record 4 of the Set 3 | gandorhun
# Processing Record 5 of the Set 3 | abalak
# Processing Record 6 of the Set 3 | cacheu
# Processing Record 7 of the Set 3 | tahoua
# Processing Record 8 of the Set 3 | atar
# Processing Record 9 of the Set 3 | kaduqli
# Processing Record 10 of the Set 3 | dakoro
# Processing Record 11 of the Set 3 | kumba
# Processing Record 12 of the Set 3 | ayame
# Processing Record 13 of the Set 3 | koulamoutou
# Processing Record 14 of the Set 3 | natal
# Processing Record 15 of the Set 3 | agadez
# Processing Record 16 of the Set 3 | makurdi
# Processing Record 17 of the Set 3 | pitimbu
# City not found. Skipping...
# Processing Record 18 of the Set 3 | cabedelo
# Processing Record 19 of the Set 3 | bafoulabe
# Processing Record 20 of the Set 3 | mao
# Processing Record 21 of the Set 3 | kaniama
# Processing Record 22 of the Set 3 | abonnema
# Processing Record 23 of the Set 3 | basse
# Processing Record 24 of the Set 3 | ler
# Processing Record 25 of the Set 3 | gao
# Processing Record 26 of the Set 3 | kampene
# Processing Record 27 of the Set 3 | dabakala
# Processing Record 28 of the Set 3 | nikki
# Processing Record 29 of the Set 3 | bokoro
# Processing Record 30 of the Set 3 | bundibugyo
# Processing Record 31 of the Set 3 | kabo
# Processing Record 32 of the Set 3 | kidal
# Processing Record 33 of the Set 3 | luba
# City not found. Skipping...
# Processing Record 34 of the Set 3 | makokou
# Processing Record 35 of the Set 3 | tema
# Processing Record 36 of the Set 3 | lolodorf
# Processing Record 37 of the Set 3 | tibati
# Processing Record 38 of the Set 3 | zemio
# Processing Record 39 of the Set 3 | tshikapa
# Processing Record 40 of the Set 3 | bida
# Processing Record 41 of the Set 3 | binga
# Processing Record 42 of the Set 3 | bossembele
# Processing Record 43 of the Set 3 | buta
# Processing Record 44 of the Set 3 | ogbomosho
# Processing Record 45 of the Set 3 | natitingou
# Processing Record 46 of the Set 3 | luebo
# Processing Record 47 of the Set 3 | mindelo
# Processing Record 48 of the Set 3 | abu zabad
# Processing Record 49 of the Set 3 | kikwit
# Processing Record 50 of the Set 3 | arlit
# Processing Record 1 of the Set 4 | douentza
# Processing Record 2 of the Set 4 | grand-lahou
# Processing Record 3 of the Set 4 | yangambi
# Processing Record 4 of the Set 4 | kontagora
# Processing Record 5 of the Set 4 | lokoja
# Processing Record 6 of the Set 4 | diffa
# Processing Record 7 of the Set 4 | agboville
# Processing Record 8 of the Set 4 | kintampo
# Processing Record 9 of the Set 4 | porto novo
# Processing Record 10 of the Set 4 | kongolo
# Processing Record 11 of the Set 4 | bossangoa
# Processing Record 12 of the Set 4 | mossendjo
# Processing Record 13 of the Set 4 | goundam
# Processing Record 14 of the Set 4 | kafanchan
# Processing Record 15 of the Set 4 | siguiri
# Processing Record 16 of the Set 4 | butembo
# Processing Record 17 of the Set 4 | boffa
# Processing Record 18 of the Set 4 | ziniare
# Processing Record 19 of the Set 4 | djambala
# Processing Record 20 of the Set 4 | gisenyi
# Processing Record 21 of the Set 4 | gaoual
# Processing Record 22 of the Set 4 | babanusah
# Processing Record 23 of the Set 4 | isiro
# Processing Record 24 of the Set 4 | adzope
# Processing Record 25 of the Set 4 | koulikoro
# Processing Record 26 of the Set 4 | kananga
# Processing Record 27 of the Set 4 | oum hadjer
# Processing Record 28 of the Set 4 | tillabery
# Processing Record 29 of the Set 4 | mbandaka
# Processing Record 30 of the Set 4 | loandjili
# Processing Record 31 of the Set 4 | dunkwa
# Processing Record 32 of the Set 4 | san-pedro
# Processing Record 33 of the Set 4 | sikasso
# Processing Record 34 of the Set 4 | linguere
# City not found. Skipping...
# Processing Record 35 of the Set 4 | ouango
# Processing Record 36 of the Set 4 | birao
# Processing Record 37 of the Set 4 | sibut
# Processing Record 38 of the Set 4 | bongandanga
# Processing Record 39 of the Set 4 | segou
# Processing Record 40 of the Set 4 | bousso
# Processing Record 41 of the Set 4 | boende
# Processing Record 42 of the Set 4 | basoko
# Processing Record 43 of the Set 4 | ejura
# Processing Record 44 of the Set 4 | kisangani
# Processing Record 45 of the Set 4 | tabou
# Processing Record 46 of the Set 4 | alindao
# Processing Record 47 of the Set 4 | jalingo
# Processing Record 48 of the Set 4 | bibiani
# Processing Record 49 of the Set 4 | bukama
# Processing Record 50 of the Set 4 | mekhe
# Processing Record 1 of the Set 5 | cabinda
# Processing Record 2 of the Set 5 | ibadan
# Processing Record 3 of the Set 5 | paoua
# Processing Record 4 of the Set 5 | nara
# Processing Record 5 of the Set 5 | bitkine
# Processing Record 6 of the Set 5 | kaya
# Processing Record 7 of the Set 5 | ayorou
# Processing Record 8 of the Set 5 | saurimo
# Processing Record 9 of the Set 5 | kita
# Processing Record 10 of the Set 5 | matadi
# Processing Record 11 of the Set 5 | beni
# Processing Record 12 of the Set 5 | mangai
# Processing Record 13 of the Set 5 | bangolo
# Processing Record 14 of the Set 5 | mwene-ditu
# Processing Record 15 of the Set 5 | podor
# Processing Record 16 of the Set 5 | yambio
# Processing Record 17 of the Set 5 | savelugu
# Processing Record 18 of the Set 5 | bangangte
# Processing Record 19 of the Set 5 | mobaye
# Processing Record 20 of the Set 5 | bouna
# Processing Record 21 of the Set 5 | rafai
# Processing Record 22 of the Set 5 | manjo
# Processing Record 23 of the Set 5 | tokonou
# Processing Record 24 of the Set 5 | buchanan
# Processing Record 25 of the Set 5 | kango
# Processing Record 26 of the Set 5 | odienne
# Processing Record 27 of the Set 5 | loubomo
# Processing Record 28 of the Set 5 | sapouy
# Processing Record 29 of the Set 5 | banamba
# Processing Record 30 of the Set 5 | vila do maio
# Processing Record 31 of the Set 5 | gitarama
# Processing Record 32 of the Set 5 | uvira
# Processing Record 33 of the Set 5 | lisala
# Processing Record 34 of the Set 5 | jos
# Processing Record 35 of the Set 5 | ikole
# Processing Record 36 of the Set 5 | nola
# Processing Record 37 of the Set 5 | madingou
# Processing Record 38 of the Set 5 | agnibilekrou
# Processing Record 39 of the Set 5 | mbour
# Processing Record 40 of the Set 5 | camabatela
# Processing Record 41 of the Set 5 | nouadhibou
# Processing Record 42 of the Set 5 | numan
# Processing Record 43 of the Set 5 | berberati
# Processing Record 44 of the Set 5 | sassandra
# Processing Record 45 of the Set 5 | ouallam
# Processing Record 46 of the Set 5 | bol
# Processing Record 47 of the Set 5 | caxito
# Processing Record 48 of the Set 5 | kabinda
# Processing Record 49 of the Set 5 | maiduguri
# Processing Record 50 of the Set 5 | mbuji-mayi
# Processing Record 1 of the Set 6 | kindu
# Processing Record 2 of the Set 6 | beboto
# Processing Record 3 of the Set 6 | akim swedru
# Processing Record 4 of the Set 6 | tenenkou
# Processing Record 5 of the Set 6 | faya
# Processing Record 6 of the Set 6 | bosobolo
# Processing Record 7 of the Set 6 | obo
# Processing Record 8 of the Set 6 | aketi
# Processing Record 9 of the Set 6 | filingue
# Processing Record 10 of the Set 6 | biu
# Processing Record 11 of the Set 6 | touba
# Processing Record 12 of the Set 6 | ouesso
# Processing Record 13 of the Set 6 | moba
# Processing Record 14 of the Set 6 | mimongo
# Processing Record 15 of the Set 6 | nisia floresta
# Processing Record 16 of the Set 6 | zinder
# Processing Record 17 of the Set 6 | biltine
# Processing Record 18 of the Set 6 | tsogni
# Processing Record 19 of the Set 6 | manono
# Processing Record 20 of the Set 6 | ilorin
# Processing Record 21 of the Set 6 | mumford
# Processing Record 22 of the Set 6 | youkounkoun
# Processing Record 23 of the Set 6 | bembereke
# Processing Record 24 of the Set 6 | idah
# Processing Record 25 of the Set 6 | cape coast
# Processing Record 26 of the Set 6 | gashua
# Processing Record 27 of the Set 6 | businga
# Processing Record 28 of the Set 6 | ndjole
# Processing Record 29 of the Set 6 | navrongo
# Processing Record 30 of the Set 6 | winneba
# Processing Record 31 of the Set 6 | soubre
# Processing Record 32 of the Set 6 | maine-soroa
# Processing Record 33 of the Set 6 | bambey
# Processing Record 34 of the Set 6 | koundara
# Processing Record 35 of the Set 6 | garoua
# Processing Record 36 of the Set 6 | douala
# Processing Record 37 of the Set 6 | bakel
# Processing Record 38 of the Set 6 | adre
# Processing Record 39 of the Set 6 | kyabe
# Processing Record 40 of the Set 6 | bandiagara
# Processing Record 41 of the Set 6 | ikom
# Processing Record 42 of the Set 6 | bomi
# Processing Record 43 of the Set 6 | lafiagi
# Processing Record 44 of the Set 6 | bogande
# Processing Record 45 of the Set 6 | marawi
# Processing Record 46 of the Set 6 | dekoa
# Processing Record 47 of the Set 6 | bumba
# Processing Record 48 of the Set 6 | daoukro
# Processing Record 49 of the Set 6 | bertoua
# Processing Record 50 of the Set 6 | mushie
# Processing Record 1 of the Set 7 | bria
# Processing Record 2 of the Set 7 | cotonou
# Processing Record 3 of the Set 7 | moissala
# Processing Record 4 of the Set 7 | gollere
# Processing Record 5 of the Set 7 | bende
# Processing Record 6 of the Set 7 | bama
# Processing Record 7 of the Set 7 | dabou
# Processing Record 8 of the Set 7 | diapaga
# Processing Record 9 of the Set 7 | bondo
# Processing Record 10 of the Set 7 | goundi
# Processing Record 11 of the Set 7 | ribeira brava
# Processing Record 12 of the Set 7 | dinguiraye
# Processing Record 13 of the Set 7 | bocaranga
# Processing Record 14 of the Set 7 | ndioum
# Processing Record 15 of the Set 7 | ati
# Processing Record 16 of the Set 7 | obuasi
# Processing Record 17 of the Set 7 | nioki
# Processing Record 18 of the Set 7 | diebougou
# Processing Record 19 of the Set 7 | toulepleu
# Processing Record 20 of the Set 7 | salaga
# Processing Record 21 of the Set 7 | kasiri
# Processing Record 22 of the Set 7 | kumbo
# Processing Record 23 of the Set 7 | jega
# Processing Record 24 of the Set 7 | benoy
# Processing Record 25 of the Set 7 | kolondieba
# Processing Record 26 of the Set 7 | adiake
# Processing Record 27 of the Set 7 | dire
# Processing Record 28 of the Set 7 | betare oya
# Processing Record 29 of the Set 7 | gaoua
# Processing Record 30 of the Set 7 | tivaouane
# Processing Record 31 of the Set 7 | libreville
# Processing Record 32 of the Set 7 | jacqueville
# Processing Record 33 of the Set 7 | niono
# Processing Record 34 of the Set 7 | nkoteng
# Processing Record 35 of the Set 7 | agogo
# Processing Record 36 of the Set 7 | abong mbang
# Processing Record 37 of the Set 7 | gorom-gorom
# Processing Record 38 of the Set 7 | bara
# Processing Record 39 of the Set 7 | kollo
# Processing Record 40 of the Set 7 | sarh
# Processing Record 41 of the Set 7 | igbo ora
# Processing Record 42 of the Set 7 | ugep
# Processing Record 43 of the Set 7 | pobe
# Processing Record 44 of the Set 7 | lagdo
# Processing Record 45 of the Set 7 | bobo dioulasso
# Processing Record 46 of the Set 7 | meiganga
# Processing Record 47 of the Set 7 | acurenam
# Processing Record 48 of the Set 7 | bubanza
# Processing Record 49 of the Set 7 | tessalit
# Processing Record 50 of the Set 7 | cibitoke
# Processing Record 1 of the Set 8 | hounde
# Processing Record 2 of the Set 8 | teshie
# Processing Record 3 of the Set 8 | faranah
# Processing Record 4 of the Set 8 | funtua
# Processing Record 5 of the Set 8 | opobo
# Processing Record 6 of the Set 8 | katiola
# Processing Record 7 of the Set 8 | duku
# Processing Record 8 of the Set 8 | tanda
# Processing Record 9 of the Set 8 | kpagouda
# Processing Record 10 of the Set 8 | berekum
# Processing Record 11 of the Set 8 | swedru
# Processing Record 12 of the Set 8 | dahra
# Processing Record 13 of the Set 8 | ondo
# Processing Record 14 of the Set 8 | gunjur
# Processing Record 15 of the Set 8 | nanga eboko
# Processing Record 16 of the Set 8 | maghama
# Processing Record 17 of the Set 8 | mopti
# Processing Record 18 of the Set 8 | uige
# Processing Record 19 of the Set 8 | lubao
# Processing Record 20 of the Set 8 | mbini
# Processing Record 21 of the Set 8 | hohoe
# Processing Record 22 of the Set 8 | suleja
# Processing Record 23 of the Set 8 | anisoc
# Processing Record 24 of the Set 8 | owando
# Processing Record 25 of the Set 8 | kuntaur
# Processing Record 26 of the Set 8 | dori
# Processing Record 27 of the Set 8 | tambacounda
# Processing Record 28 of the Set 8 | batie
# Processing Record 29 of the Set 8 | ilebo
# Processing Record 30 of the Set 8 | gamboula
# Processing Record 31 of the Set 8 | magaria
# Processing Record 32 of the Set 8 | fatick
# Processing Record 33 of the Set 8 | kano
# Processing Record 34 of the Set 8 | mongomo
# Processing Record 35 of the Set 8 | akonolinga
# Processing Record 36 of the Set 8 | saltpond
# Processing Record 37 of the Set 8 | kolokani
# Processing Record 38 of the Set 8 | sokolo
# Processing Record 39 of the Set 8 | gayeri
# Processing Record 40 of the Set 8 | kangaba
# Processing Record 41 of the Set 8 | banfora
# Processing Record 42 of the Set 8 | koupela
# Processing Record 43 of the Set 8 | ankpa
# Processing Record 44 of the Set 8 | mvangue
# Processing Record 45 of the Set 8 | kpandae
# Processing Record 46 of the Set 8 | banyo
# Processing Record 47 of the Set 8 | yirol
# Processing Record 48 of the Set 8 | yola
# Processing Record 49 of the Set 8 | kongoussi
# Processing Record 50 of the Set 8 | pitmoaga
# Processing Record 1 of the Set 9 | gberia fotombu
# Processing Record 2 of the Set 9 | ngaoundere
# Processing Record 3 of the Set 9 | biankouma
# Processing Record 4 of the Set 9 | dabola
# Processing Record 5 of the Set 9 | mora
# Processing Record 6 of the Set 9 | mandiana
# Processing Record 7 of the Set 9 | damara
# Processing Record 8 of the Set 9 | kpalime
# Processing Record 9 of the Set 9 | katsina
# Processing Record 10 of the Set 9 | tarrafal
# Processing Record 11 of the Set 9 | fougamou
# Processing Record 12 of the Set 9 | zaria
# Processing Record 13 of the Set 9 | mbanza-ngungu
# Processing Record 14 of the Set 9 | notse
# Processing Record 15 of the Set 9 | sembe
# Processing Record 16 of the Set 9 | waw
# Processing Record 17 of the Set 9 | uwayl
# Processing Record 18 of the Set 9 | oyo
# Processing Record 19 of the Set 9 | brufut
# Processing Record 20 of the Set 9 | mubi
# Processing Record 21 of the Set 9 | illela
# Processing Record 22 of the Set 9 | potiskum
# Processing Record 23 of the Set 9 | solenzo
# Processing Record 24 of the Set 9 | ippy
# Processing Record 25 of the Set 9 | ferkessedougou
# Processing Record 26 of the Set 9 | oyem
# Processing Record 27 of the Set 9 | enugu
# Processing Record 28 of the Set 9 | malumfashi
# Processing Record 29 of the Set 9 | kayes
# Processing Record 30 of the Set 9 | kolda
# Processing Record 31 of the Set 9 | dibaya
# Processing Record 32 of the Set 9 | tibiri
# Processing Record 33 of the Set 9 | save
# Processing Record 34 of the Set 9 | kasangulu
# Processing Record 35 of the Set 9 | toma
# Processing Record 36 of the Set 9 | kinkala
# Processing Record 37 of the Set 9 | macenta
# Processing Record 38 of the Set 9 | niamey
# Processing Record 39 of the Set 9 | booue
# Processing Record 40 of the Set 9 | kindia
# Processing Record 41 of the Set 9 | ouahigouya
# Processing Record 42 of the Set 9 | say
# Processing Record 43 of the Set 9 | aneho
# Processing Record 44 of the Set 9 | bunia
# Processing Record 45 of the Set 9 | bouar
# Processing Record 46 of the Set 9 | abeche
# Processing Record 47 of the Set 9 | bassar
# Processing Record 48 of the Set 9 | tignere
# Processing Record 49 of the Set 9 | mongo
# Processing Record 50 of the Set 9 | obala
# Processing Record 1 of the Set 10 | gbadolite
# Processing Record 2 of the Set 10 | bekwai
# Processing Record 3 of the Set 10 | bonoua
# Processing Record 4 of the Set 10 | luau
# Processing Record 5 of the Set 10 | zorgo
# Processing Record 6 of the Set 10 | gandajika
# Processing Record 7 of the Set 10 | bamako
# Processing Record 8 of the Set 10 | malabo
# Processing Record 9 of the Set 10 | seguela
# Processing Record 10 of the Set 10 | sibiti
# Processing Record 11 of the Set 10 | okandja
# Processing Record 12 of the Set 10 | ila
# Processing Record 13 of the Set 10 | bindi
# Processing Record 14 of the Set 10 | tchibanga
# Processing Record 15 of the Set 10 | assomada
# Processing Record 16 of the Set 10 | vogan
# Processing Record 17 of the Set 10 | fontem
# Processing Record 18 of the Set 10 | nsukka
# Processing Record 19 of the Set 10 | lokossa
# Processing Record 20 of the Set 10 | njinikom
# Processing Record 21 of the Set 10 | tingrela
# Processing Record 22 of the Set 10 | poli
# Processing Record 23 of the Set 10 | zwedru
# Processing Record 24 of the Set 10 | dourbali
# Processing Record 25 of the Set 10 | seidu
# Processing Record 26 of the Set 10 | bogo
# Processing Record 27 of the Set 10 | epe
# Processing Record 28 of the Set 10 | dapaong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Import Pandas
import pandas as pd

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Raga   8.4596   25.6780     77.41        70         100
# 1       Tambura   8.4596   25.6780     77.41        70         100
# 2      Impfondo   1.6381   18.0667     75.65        81          45
# 3       Sal Rei  16.1833  -22.9167     88.00        48           0
# 4        Touros  -5.1989  -35.4608     88.70        62          61
# 5   Saint-Louis  16.3333  -15.0000     98.24         7          41
# 6     Bangassou   4.7413   22.8184     74.59        80          85
# 7       Kalemie  -5.9475   29.1947     74.68        79         100
# 8    Georgetown   5.4112  100.3354     80.89        90          40
# 9  Umm Kaddadah   8.4596   25.6780     77.41        70         100
#
#    Wind Speed Country Current Description
# 0        3.62      SS     overcast clouds
# 1        3.62      SS     overcast clouds
# 2        0.56      CG    scattered clouds
# 3       18.41      CV           clear sky
# 4       13.13      BR       broken clouds
# 5       10.04      SN    scattered clouds
# 6        1.70      CF     overcast clouds
# 7        7.11      CD     overcast clouds
# 8        3.44      MY    scattered clouds
# 9        3.62      SS     overcast clouds

# %%
# reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Current Description", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]                        

city_data_df
# Out:
#          City Country      Lat      Lng  Max Temp Current Description  \
# 0        Raga      SS   8.4596  25.6780     77.41     overcast clouds
# 1     Tambura      SS   8.4596  25.6780     77.41     overcast clouds
# 2    Impfondo      CG   1.6381  18.0667     75.65    scattered clouds
# 3     Sal Rei      CV  16.1833 -22.9167     88.00           clear sky
# 4      Touros      BR  -5.1989 -35.4608     88.70       broken clouds
# ..        ...     ...      ...      ...       ...                 ...
# 469  Dourbali      TD  11.0297  20.2827     83.14    scattered clouds
# 470     Seidu      SL   7.6244 -11.8332     78.03          light rain
# 471      Bogo      CM   3.5167  15.0500     71.29          light rain
# 472       Epe      NG  12.4539   4.1975     93.87       broken clouds
# 473   Dapaong      TG   7.4667   0.9000     78.85       moderate rain
#
#      Humidity  Cloudiness  Wind Speed
# 0          70         100        3.62
# 1          70         100        3.62
# 2          81          45        0.56
# 3          48           0       18.41
# 4          62          61       13.13
# ..        ...         ...         ...
# 469        55          28        5.26
# 470        92          97        5.44
# 471        96          87        2.08
# 472        34          70        4.65
# 473        83          42        1.12
#
# [474 rows x 9 columns]

# %%
# Export the DataFrame as a CSV file and save as WeatherPy_Database.csv
output_data_file = "cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
